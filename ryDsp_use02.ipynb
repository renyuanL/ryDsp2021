# %%
import ryDsp
from ryDsp import *


    
#sr, wav= getWavFromYoutube()

mp3File= '江蕙-家後.mp3'
sr, w= ryDsp.getWavFromFile_mp3(mp3File)
ryDsp.playWav(w, sr)
sr, w
wav= w
# Out:
# cmd= ffmpeg -y -i "江蕙-家後.mp3" "江蕙-家後.mp3.wav"
# playWav, sr= 44100, duration= 252.378 sec

# %%
#time.sleep(1)
#input('after playing, press any key to continue..')

x= wav[sr*100:sr*120, :]
plotWav(wav, sr*10//9)
playWav(wav, sr*10//9)
# Out:
# playWav, sr= 49000, duration= 227.140 sec

# %%
#time.sleep(1)
#input('after playing, press any key to continue..')

x= wav[sr*100:sr*120, 0]
plotWav(wav, sr*9//10)
playWav(wav, sr*9//10)
# Out:
# playWav, sr= 39690, duration= 280.420 sec

# %%
#time.sleep(1)
#input('after playing, press any key to continue..')

x=  wav[sr*100:sr*120, 0]
xx= filterWav(x, sr, cutoff_freq= 1000, lowpass=True)
playWav(xx,sr)
plotWav(xx,sr)
# Out:
# lowpass, cutoff_freq= 1000 Hz
# playWav, sr= 44100, duration= 20.000 sec

# %%
#time.sleep(1)
#input('after playing, press any key to continue..')

x=  wav[sr*100:sr*120, 0]
xx= filterWav(x, sr, cutoff_freq= 1000, lowpass=False)
playWav(xx,sr)
plotWav(xx,sr)
# Out:
# highpass, cutoff_freq= 1000 Hz
# playWav, sr= 44100, duration= 20.000 sec

# %%
#time.sleep(1)
#input('after playing, press any key to continue..')

# %%
π= np.pi

def genSinSignal(T=1, f= 440, A=1, ϕ=0, sr= 44100):
    ts= np.linspace(0, T, sr*T)
    θ= 2 *π  *f *ts + ϕ
    ys= A * np.sin(θ)
    return sr, ys

def genCosSignal(T=1, f= 440, A=1, ϕ=0, sr= 44100):
    ts= np.linspace(0, T, sr*T)
    θ= 2 *π  *f *ts + ϕ
    ys= A * np.cos(θ)
    return sr, ys

sr, ys= genCosSignal()

# %%
import ryDsp

# %%
ryDsp.plotWav(ys, sr)

# %%
ryDsp.playWav(ys,sr)
# Out:
# playWav, sr= 44100, duration= 1.000 sec

# %%
sr, ys= genCosSignal(f=440)
ryDsp.playWav(ys,sr)
# Out:
# playWav, sr= 44100, duration= 1.000 sec

# %%
sr, ys= genSinSignal(f=440)
ryDsp.playWav(ys,sr)
# Out:
# playWav, sr= 44100, duration= 1.000 sec

# %%
def genSquareSignal(T=1, f= 440, A=1, ϕ=0, sr= 44100):

    sr, ys= genSinSignal(T, f, A, ϕ, sr)
    ys= np.sign(ys)
    return sr, ys

sr, ys= genSquareSignal(f=440)
ryDsp.playWav(ys,sr)
# Out:
# playWav, sr= 44100, duration= 1.000 sec

# %%
ryDsp.plotWav(ys[:sr//100],sr)

# %%
def genTriangleSignal(T=1, f= 440, A=1, ϕ=0, sr= 44100):
    ts= np.linspace(0, T, sr*T)
    θ= 2 *π  *f *ts + ϕ
    cycles= θ/(2 *π)
    frac, _ = np.modf(cycles)
    ys= np.abs(frac-.5) - .5/2
    ys= ys*4*A
    
    #ys= A * np.sin(θ)
    
    return sr, ys

sr, ys= genTriangleSignal(f=440)

ryDsp.plotWav(ys[:sr//100],sr)
ryDsp.playWav(ys,sr)
# Out:
# playWav, sr= 44100, duration= 1.000 sec

# %%
sr, ys= genSquareSignal(f=440)

ryDsp.plotWav(ys[:sr//100],sr)
ryDsp.playWav(ys,sr)
# Out:
# playWav, sr= 44100, duration= 1.000 sec

# %%
def genSawtoothSignal(T=1, f= 440, A=1, ϕ=0, sr= 44100):
    ts= np.linspace(0, T, sr*T)
    θ= 2 *π  *f *ts + ϕ
    cycles= θ/(2 *π)
    frac, _ = np.modf(cycles)
    ys= np.abs(frac) - .5
    ys= ys*2*A
    
    #ys= A * np.sin(θ)
    
    return sr, ys

sr, ys= genSawtoothSignal(f=440)

ryDsp.plotWav(ys[:sr//100],sr)
ryDsp.playWav(ys,sr)
# Out:
# playWav, sr= 44100, duration= 1.000 sec

# %%
## how about multiply a square (triangle) signal onto the original song-signal ??
#sr, ys= genSquareSignal(f= 10)

sr, ys= genTriangleSignal(f= 300)


ryDsp.plotWav(ys)
ryDsp.playWav(ys,sr)
# Out:
# playWav, sr= 44100, duration= 1.000 sec

# %%
wav.shape
# Out:
# (11129856, 2)

# %%
sr= 44100
ryDsp.playWav(wav,sr)
# Out:
# playWav, sr= 44100, duration= 252.378 sec

# %%
sr1, ys= genSquareSignal(T= wav.shape[0], f= 100, sr=1)

sr1, ys= genTriangleSignal(T= wav.shape[0], f= 100, sr=1)

# %%
ys= (ys+1)/2

# %%
ys.shape
# Out:
# (44100,)

# %%
q= wav*ys.reshape(-1,1)
ryDsp.playWav(q, sr= 44100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-66a2c6095d41> in <module>
# ----> 1 q= wav*ys.reshape(-1,1)
#       2 ryDsp.playWav(q, sr= 44100)
#
# ValueError: operands could not be broadcast together with shapes (11129856,2) (44100,1)

# %%
pl.plot(q)

# %%
# %matplotlib qt
pl.plot(q)

# %%
# apodize the beginning and the ending part of the wav
wav

# %%
T0= wav.shape[0]
T1=T0//3
T2=T0//3
win0= np.linspace(0,1, T1)
win1= np.ones(T0-T1-T2)
win2= np.linspace(1,0, T2)
win= apodizeWindow= np.concatenate((win0, win1, win2)) 
pl.plot(win)

# %%
win= win.reshape(-1,1)
wav1= wav*win
ryDsp.plotWav(wav1)

# %%
ryDsp.playWav(wav1, sr)

# %%
# wrapping the above code segments into a function
wav

def apodizeWave(wav, starting_ratio=1/2, ending_ratio=1/2):
    
    assert starting_ratio <= 1/2
    assert ending_ratio <= 1/2
    
    T0= wav.shape[0]
    T1= int(T0 * starting_ratio)
    T2= int(T0 * ending_ratio)
    win0= np.linspace(0,1, T1)
    win1= np.ones(T0-T1-T2)
    win2= np.linspace(1,0, T2)
    win=  np.concatenate((win0, win1, win2)) 
    win=  win.reshape(-1,1)
    q= wav*win
    
    return q

wav1= apodizeWave(wav[sr*100:sr*120,:], 1/2, 1/2)
ryDsp.playWav(wav1, sr)
