# %%
from ryDsp import *
    
sr, wav= getWavFromYoutube()
# Out:
# url= https://youtu.be/HBUwoAoScaQ, info= 手嶌 葵《テルーの唄 》中日字幕

# %%
y= apodizeWav(wav, starting_ratio=1/2, ending_ratio=1/2)
plotWav(y)

# %%
y= apodizeWav(wav, starting_ratio=1/3, ending_ratio=1/3)
plotWav(y)

# %%
y= apodizeWav(wav, starting_ratio=1/2, ending_ratio=1/2)
plotWav(y)

# %%
y= apodizeWav(wav[sr*100:sr*120,:], starting_ratio=1/2, ending_ratio=1/2)
plotWav(y)
playWav(y, sr)
# Out:
# playWav, sr= 44100, duration= 20.000 sec
